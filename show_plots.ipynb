# %%
import glob
from IPython.display import Image, display
import drawing_plots

# %%
files = drawing_plots.DrawingPlots().draw_plots('deviation.json')
files
# Out:
# ['plots/columns_correlation_heatmap.png',
#  'plots/samples_percentage_per_corners_num.png',
#  'plots/accuracy_per_corners_num.png',
#  'plots/samples_amount_per_corners_num.png']

# %%
plots = glob.glob("plots/*")

# %%
for pl in plots:
    display(Image(filename=pl))
